# %% [markdown]
# ## Filtering repoDB to find successful and failed drug repurposing
#
# Data from http://apps.chiragjpgroup.org/repoDB/
#
# Information about terms available here
# https://clinicaltrials.gov/ct2/about-studies/glossary

# %%
import collections
import re

import pandas as pd

# %%
df = pd.read_csv('repoDB.csv')

success_df = df.query('status == "Approved"').assign(label=1)
fail_df = df.query('status != "Approved"').assign(label=0)

df.head(2)
# Out:
#    drug_name  drug_id                                          ind_name  \
# 0  Lepirudin  DB00001  Heparin-induced thrombocytopenia with thrombosis
# 1  Cetuximab  DB00002                  Squamous cell carcinoma of mouth
#
#      ind_id  NCT    status phase DetailedStatus
# 0  C0272275  NaN  Approved   NaN            NaN
# 1  C0585362  NaN  Approved   NaN            NaN

# %% [markdown]
# ### Imperfect manual curation of function failures
#
# Many clinical trials are not completed due to administrative reasons, such as a failure to recruit participants. These should be filtered as the actual treatment effect remains unknown.

# %%
fail_df['functional_failure'] = (fail_df['DetailedStatus']
.apply(lambda x: 
       not pd.isna(x)
       and 'complete' not in str(x).lower()
       and 'accru' not in str(x).lower()  # accrual and accrue
       and 'enrol' not in str(x).lower()
       and 'fund' not in str(x).lower()
       and 'recruit' not in str(x).lower()
       and 'availab' not in str(x).lower()
       and 'pi' not in str(x).lower()
       and 'p.i.' not in str(x).lower()
       and 'insurance' not in str(x).lower()
       and 'competitor' not in str(x).lower()
       and 'business' not in str(x).lower()
       and 'supply' not in str(x).lower()
       and 'access' not in str(x).lower()
       and 'eligib' not in str(x).lower()
       and 'admin' not in str(x).lower()
       and 'license' not in str(x).lower()
       and x != 'withdrawn'
       and x != 'New study written'
       and x != 'drug now on market'
      )
)

# %%
collections.Counter(fail_df[fail_df['functional_failure'] == True]['DetailedStatus']).most_common()
# Out:
# [('Temporarily stopped for assessment', 50),
#  ('Major revisions needed in study', 48),
#  ('Financial Sponsor requested termination', 36),
#  ('This study will not be written up.', 35),
#  ('Discontinued development of G3139 (oblimersen)', 20),
#  ('due to safety concerns and lack of efficacy', 16),
#  ('Unacceptable morbidity & mortality', 12),
#  ('Increased rate of bacterial infections', 10),
#  ('Sponsor withdrew support; Study did not progress to Phase II.', 9),
#  ('Trial was terminated to allow sponsors to evaluate the future development of the drug program',
#   9),
#  ('Sponsor withdrew support; Study did not progress to Phase II (Phase I registration    NCT00895960)',
#   9),
#  ('The study was not activated.', 8),
#  ('See termination reason in detailed description.', 8),
#  ('Extreme toxicity of Pertuzumab and Erlotinib combination', 8),
#  ('The study was stopped due to the inability to determine an acceptable dose with the potential    for further study',
#   8),
#  ('Data from the C08 study and Avant study', 7),
#  ('See termination reason in detailed description', 7),
#  ('This study was closed early by the DSMB due to increased toxicity.', 7),
#  ('See Detailed Description', 6),
#  ('inactive', 6),
#  ('Withdrawn by the study sponsor.', 6),
#  ('Company decided to stop development of drug - 7/31/12', 6),
#  ('Research Cancelled', 6),
#  ('No progression of Phase 1 trial to Phase 2.', 6),
#  ('Temporarily stopped for assessment. Contact ctsucontact@westat.com for specifics',
#   6),
#  ('Temporarily stopped for assessment.', 6),
#  ('Terminated due to bevacizumab and chemoradiotherapy toxicity', 5),
#  ('Terminated', 5),
#  ('Terminated by Sponsor', 5),
#  ('Investigator decision', 5),
#  ('Objectives not met.', 5),
#  ('Study closed by the NCI.', 4),
#  ('Closed due to competing protocols', 4),
#  ('It was unlikely that the primary endpoint would be reached based on the fifth interim analysis    results.',
#   4),
#  ('IRB Study Closure', 4),
#  ('MTD not determined', 4),
#  ('The major and primary reason for the study termination is the observed reduced efficacy of    CellCept compared to placebo.',
#   4),
#  ('Terminated due to withdrawal of support from our collaborator.', 4),
#  ('ONTAK has been pulled off the market for further testing. Subsequently, EISAI will no longer    be supporting clinical trials that utilize this drug.',
#   4),
#  ('Interim analysis', 4),
#  ('Study is no longer required by Brazil health authority.', 4),
#  ('Manufacturer discontinued drug development.', 4),
#  ('Awaiting response from FDA as to status of parenteral ascorbic acid manufactured by Bioniche    (Ireland).',
#   4),
#  ('The company (Enzon Pharmaceuticals)providing the drug EZN-3042 decided to end its development    of EZN-3042.',
#   4),
#  ('lack of personnel resource and protocol amendment needed', 4),
#  ('Unexpected toxicities, likely due to TIL/IL-12 & low % of durable responses.',
#   4),
#  ("Per sponsor's decision", 4),
#  ('efficacy interim analysis as per protocol', 4),
#  ('Feasibility of the trial was proven to be absent.', 4),
#  ('Due to potential competition with a post-marketing study requested by FDA',
#   4),
#  ('Study on hold due to primary co-investigator leaving the institution.', 4),
#  ('safety reasons', 3),
#  ('Toxicity', 3),
#  ('The study was terminated prior to completion to focus on the development of a controlled    release formulation.',
#   3),
#  ('Sponsor decision', 3),
#  ('wothdrawal of sponsor', 3),
#  ('short of participants', 3),
#  ('Safety reasons', 3),
#  ('unexpected level of toxicity', 3),
#  ('Negative sorafenib results from ESCAPE trial and safety concerns of regimen',
#   3),
#  ('data analysis showed insufficient drug efficacy', 3),
#  ('DSMB stopped study because placebo arm had more adverse events', 3),
#  ('Based on data collected, the combination appeared to be poorly tolearated.',
#   3),
#  ('Terminated due to failure to meet the primary efficacy endpoint in the Short-term Period',
#   3),
#  ('never been started', 3),
#  ('No patients exhibited natural killer cell expansion (primary endpoint).',
#   3),
#  ('Closed early due to determination of futility/efficacy.', 3),
#  ('High patient withdrawal rate', 3),
#  ("Data Safety Monitoring Board concerning of the participants' safety", 3),
#  ('Terminated by sponsor due to new unpublished data that rendered the current design of the    study no longer clinically relevant. There were no safety concerns.',
#   3),
#  ('Study will not be intiated', 3),
#  ('The study was prematurely terminated because of unavailibility of Methylnaltrexone in the    region',
#   3),
#  ('Doxil Shortage', 3),
#  ('The Sponsor has no interest in continuing the study.', 3),
#  ('IT was impossible to find patients', 3),
#  ('Study only randomized 1 subject and was determined not feasible by DSMB',
#   3),
#  ('Refer to Detailed Description for documentaion of Termination Statement.',
#   3),
#  ('Due to safety concern of active control drug', 3),
#  ('Sponsor seeking additional financial support before starting the study', 3),
#  ('On 05/08/12, team working on revising protocol and re-open study under version 2.0',
#   3),
#  ('Non-compliance', 3),
#  ('Too slow patient inclusion and superior effect of the injection', 3),
#  ('DSMB recommended closing the study and publishing the results', 2),
#  ('Interim analysis indicated study should be terminated', 2),
#  ('Preliminary results showed increased intraventricular hemorrhage (IVH) in experimental arm',
#   2),
#  ('Not opened at Fox Chase Cancer Center', 2),
#  ('Terminated in view of the C107 findings demonstrating efficacy at doses of 90 and 30 minutes',
#   2),
#  ('The unpromising experience of the French group with topotecan given at a dosage of 0.4    mg/m2/day over 30 mins w/in 1 hr of radiation (Cancer 2005; 104: 2792).',
#   2),
#  ('Interim analysis showed the primary outcome was not reached', 2),
#  ('Program discontinued', 2),
#  ('The study was discontinued due to the death of a co-investigator and a second co-investigator    leaving the institution.',
#   2),
#  ('This was a follow-on study to Biomed 777-CLP-029 which did not meet superiority endpoint',
#   2),
#  ('FDA Hold May 2007', 2),
#  ('Insufficient evidence of the clinical effectiveness of cangrelor', 2),
#  ('Vaccine sponsor ceased operations.', 2),
#  ('Sponsor Decision', 2),
#  ('Terminated, new protocol to be developed', 2),
#  ('Refer to Detailed Description.', 2),
#  ('Study Terminated; Commitment met per Regulatory Authorities.', 2),
#  ('Halted by NICHD after recommendation by DSMC to stop for futility', 2),
#  ('pts. will be captured in core', 2),
#  ('side effect profile did not match expectations', 2),
#  ('Company decision has been taken in light of recent demands by certain national health    authorities',
#   2),
#  ('The perceived risk-benefit ratio for individuals with early active RA', 2),
#  ('The study withdrawn due to lack financial support', 2),
#  ('Local pharmacy unwilling to comply with study protocol', 2),
#  ('Carisbamate partial onset seizures studies lacked consistent efficacy data so trials in this    indication were terminated.',
#   2),
#  ('OncoGel did not show any impact on overall tumor response', 2),
#  ('The study was terminated due to unanticipated safety issues', 2),
#  ('Replaced by another study', 2),
#  ("Sponsor's decision", 2),
#  ('Dr. Jorizzo has decided to withdraw from this study due to the time it is taking to get the    study started.',
#   2),
#  ('Malaria prev. fell in the study area, so we cannot evaluate the primary endpoint',
#   2),
#  ('financial constraints', 2),
#  ('Investigator no longer at university', 2),
#  ('We are currently performing and interim analysis for possible neonatal organism resistance to    antibiotic regimens.',
#   2),
#  ('MTD determined sub-optimal as efficacious treatment for renal cell carcinoma.',
#   2),
#  ('Study has been stopped by sponsor decision', 2),
#  ('The study is terminated prematurely as the sponsor decided to discontinue program with EMD    525797 in oncology.',
#   2),
#  ('AstraZeneca has discontinued the development of AZD0530. No new AstraZeneca-sponsored clinical    studies will be initiated..',
#   2),
#  ('Colaborator withdrew support.', 2),
#  ('Study was withdrawn due issuses related to the science', 2),
#  ('toxicities', 2),
#  ('Preliminary data from study NCT00994214 do not support expected inhibition of GH and IGF-1',
#   2),
#  ('Failed to reach endpoints', 2),
#  ('Preliminary data from this study does not support expected inhibition of GH and IGF-1',
#   2),
#  ('Study abandoned', 2),
#  ('Lack of patient population', 2),
#  ('Lacking effect of treatment', 2),
#  ('Lost sponsorship for study drug', 2),
#  ('Study was never initiated under new location/provider group. Contract to continue was never    signed between TEVA and Kennedy Headache Center',
#   2),
#  ('Due to change in the national policy of medications', 2),
#  ('The study was terminated because we were not able to obtain the study drug.',
#   2),
#  ('abandoned', 2),
#  ('Most potential subjects had already been prescribed Cymbalta.', 2),
#  ('Drug shortage', 2),
#  ('Terminated early in agreement with Health Authorities for feasibility reasons',
#   2),
#  ('Did not begin', 2),
#  ('Study never undertaken', 2),
#  ('Study is terminated due to lack of efficacy', 2),
#  ('Clinical trial being transferred to Columbia University with the Investigator.',
#   2),
#  ('Regulatory requirement. A phase III study is being designed.', 2),
#  ('Due to change in development plan.', 2),
#  ('Never initiated. Withdrawn by sponsor.', 2),
#  ('Data did not show that the two biologic treatments impacted PMR disease activity to the same    degree as steroid treatment within a 2-week treatment period.',
#   2),
#  ('Trial not progressing toward scientific goals', 2),
#  ('Sponsor closed study', 2),
#  ('Institution decided on starting a new protocol of sedation, with another methods and that´s    why this study has not started.',
#   2),
#  ('Study site has terminated the study due to the complexity of the study', 2),
#  ('Please see Purpose Statement below', 2),
#  ('Recently published data that has shown HCQ to be safe when combined with chemo and or    radiation at even higher doses than what is used in this study.',
#   2),
#  ('Closed early due to increased hematologic toxicity and possible reduced efficacy',
#   2),
#  ('Interim analysis shows harma to one of the study arms.', 2),
#  ('Interim analysis of PK and toxicity data', 2),
#  ('HRI no longer conducting research.', 2),
#  ('Diminished rectruitment', 2),
#  ('Outcome of EXPAND study (no benefit from adding cetuximab to the first-line chemotherapy in    advanced gastric cancer in the overall patient population)',
#   2),
#  ('Previous studies have been done regarding same condition', 2),
#  ('Due to the high rate of morbidity and mortality', 2),
#  ('Due to budget limitations, the company decided to withdraw this study.', 2),
#  ('Material sponsor withdrew support', 2),
#  ('Obtained results were not good. Protocol was proved ineffective.', 2),
#  ('Potential participants had concerns about taking the study drug (methotrexate).',
#   2),
#  ('Personnel changes at study site.', 2),
#  ('Concerns regarding neonatal data', 1),
#  ('Study design changes were needed based on GIPF-001 results', 1),
#  ('Drug sold to Sanofi-Aventis who sold it to GSK; OBS no longer owns study and does not have    data.',
#   1),
#  ('Futility reasons after Independent Data Monitoring Committee interim analysis',
#   1),
#  ('European reports of liver toxicity from kava meant that the study had to stop',
#   1),
#  ('Interim analysis, infliximab did not reduce number of first relapses in GCA or cumulative    glucocorticosteroid dosage',
#   1),
#  ('drug issues', 1),
#  ('insufficient efficacy', 1),
#  ('Study prematurely discont’d 20-Apr-2006 after interim analysis suggested sample size could be    reduced without losing power. No safety concerns led to decision.',
#   1),
#  ('Pharmaceutical sponsor withdrew financial support.', 1),
#  ('Study was never initiated', 1),
#  ('trial stopped on Sept 24, 2007', 1),
#  ('Study never started.', 1),
#  ('Insufficient power to show therapy difference at interim analysis.', 1),
#  ('difficulty of recrutement', 1),
#  ('Inconsistent treatment benefit', 1),
#  ('No response seen in patients', 1),
#  ('Study was discontinued because of high drop out rate.', 1),
#  ('Non-protocol feasibility', 1),
#  ('This study has been terminated early as the esreboxetine development program is being    discontinued. There are no safety or efficacy concerns.',
#   1),
#  ('Study stopped because of toxicity concerns.', 1),
#  ('Lack of efficacy', 1),
#  ('Per Group Chair: This study will not move forward.', 1),
#  ('Primary (safety) endpoint reached', 1),
#  ('Withdrawn because protocol has been discontinued. It was never opened.', 1),
#  ('Stopped for futility by DSMB', 1),
#  ('Low Accural', 1),
#  ('Too frequent grade 3-4 toxicities', 1),
#  ('reports indicating that increased folic acid intake may increase colin cancer',
#   1),
#  ('lack of patients', 1),
#  ('Terminated due to dose limiting toxicity', 1),
#  ('At the end of the year 2002, Cameroon switched from chloroquine to amodiaquine as first-line    therapy for of uncomplicated malaria.',
#   1),
#  ("The termination of the study is not linked to a product recall or result of any safety signal.    Rather it was sponsor's commercial decision to withdraw the MA",
#   1),
#  ('TRIAL STOPPED due to a change in standard of care and the required patient numbers could no    longer be achieved',
#   1),
#  ('The primary efficacy endpoint was not met', 1),
#  ('Amgen discontinued the development of AMG706 because 20050201 did not meet its primary    objective.',
#   1),
#  ('Change of practice pattern. Green light laser', 1),
#  ('The study has finished.', 1),
#  ('Toxicity of combination from other trials', 1),
#  ('change in development plan, not due to safety concerns.', 1),
#  ('IDMC made a recommendation to stop the trial as the target for continuing to the 2nd phase was    not met.',
#   1),
#  ('Data Monitoring Committee concluded after a planned interim analysis that aflibercept added to    gemcitabine would be unable to demonstrate improved survival',
#   1),
#  ('Sponsor decision - not related to safety', 1),
#  ('Avastin approved for first-in-line treatment.', 1),
#  ('Study was terminated early due to lack of efficacy.', 1),
#  ('Trial terminated due to financial resource limitations', 1),
#  ('DSMB recommended termination based on interim outcomes analysis', 1),
#  ('Strategic direction of the sponsor changed', 1),
#  ('See Detailed Description field.', 1),
#  ('due to new safety information', 1),
#  ('Study was terminated for futility following the planned interim analysis.',
#   1),
#  ('Due to changes in portfolio review', 1),
#  ('sufficient number to reach the primary endpoint and as planned', 1),
#  ('Study never opened', 1),
#  ('The interim analysis showed no tendency in favour of the verum group. Therefore it was decided    to stop the study prematurely.',
#   1),
#  ('Please see Detailed Description for termination reason.', 1),
#  ('Male subjects were terminated due to an imbalance in prostate cancer events',
#   1),
#  ('Expected mortality rates in placebo and treatment groups lower than predicted',
#   1),
#  ('This project was not a clinical trial requiring registration', 1),
#  ('Primary endpoint not achieved', 1),
#  ("Subject recuitment halted and won't resume; subjects are no longer being treated.",
#   1),
#  ('Preliminary analysis', 1),
#  ('Interim analysis indicated low probability of clinically significant result',
#   1),
#  ('Pfizer has terminated the execution of this protocol', 1),
#  ('Principal Investigator decided to close the study early.', 1),
#  ('Modifications will be necessary before full IRB approval will be secured.',
#   1),
#  ('Drug combination is no longer pursued', 1),
#  ('not yet started', 1),
#  ('IND not obtained', 1),
#  ('Drug no longer being supplied by sponsor', 1),
#  ('Clinical trial terminated due to results from recent nonclinical studies',
#   1),
#  ('Company decision to modify the ferroquine development strategy; discontinuation not due to    safety or activity unexpected findings',
#   1),
#  ('Technical/operational issues', 1),
#  ('Excess of mortality in the treatment group created safety concerns.', 1),
#  ('This study was discontinued due to a shown lack of efficacy in the investigational agent',
#   1),
#  ('the H1N1 pandemic is now over, and fewer cases than expected were observed',
#   1),
#  ('Completion of dose escalation phase', 1),
#  ('study did not reach benchmark efficacy rule at 16 subjects', 1),
#  ('Study closed Nov 2000 by Amgen, who stopped drug delivery', 1),
#  ('The study is terminated prematurely as the sponsor decided to discontinue program with    Tecemotide in NSCLC.',
#   1),
#  ('Stopped due to futility.', 1),
#  ('stopped for futility', 1),
#  ('Poor inclusion rate.', 1),
#  ('Changes in approach to PDA therapy', 1),
#  ('Study was terminated due to sponsor portfolio decision.', 1),
#  ('Poor efficacy (2 of 31 completing participants with H.pylori eradication)',
#   1),
#  ('Sponsor halted study.', 1),
#  ('Interim analysis showed significant effect in favour of full-dose atorvastatin.',
#   1),
#  ('Terminated based on safety results from another trial', 1),
#  ('Pre-planned interim analysis.', 1),
#  ('The changing aetiology of squamous cell carcinoma of the head and neck (SCCHN).',
#   1),
#  ('Noted increased risks, greater than expected for standard of care therapy.',
#   1),
#  ('The objective response rate by more than two people are confirmed.', 1),
#  ('In a pre-planned interim analysis, OSI-774-205 met futility for efficacy with no safety    concerns. As a result, the companion trial, OSI-774-206 has been stopped',
#   1),
#  ('I am relocating to Johns Hopkins Medical Center', 1),
#  ('sponsor withdraw from this study', 1),
#  ('Original investigator left this institution, replacement investigator retired.',
#   1),
#  ('Study terminated due to a technical issue (randomization error).', 1),
#  ('Interim analysis showed that the primary endpoint would not be met.', 1),
#  ('change company strategy', 1),
#  ('Inclusion rate not as expected. Not financially possible to involve other centres.',
#   1),
#  ('The study was treminated because of low accural', 1),
#  ('Interim analysis results revealed substantial increase of patient number, with unfeasible    study prolongation.',
#   1),
#  ('To be compliant with the timelines as agreed with Paediatric Committee (PC) within the    Paediatric Investigational Plan',
#   1),
#  ('1 patient died of uncertain cause but possibly related to drug. Regulatory currently reviewing',
#   1),
#  ('Some of the researchers finished their participation in the study.', 1),
#  ('Lack of adherence and huge loss of follow up.', 1),
#  ('trial design contingent on RFA optimization', 1),
#  ('The trial was early terminated after it was concluded that there was no added benefit from    exposing further participants after an unblinded interim analysis.',
#   1),
#  ('This study was closed prematurely due study team travel restrictions.', 1),
#  ('Study was not given ethical approval- a alternative protocol required', 1),
#  ('Terminated after placing the study on hold at the request of the FDA', 1),
#  ('Protocol Revisions', 1),
#  ('Unexpected toxicity (2 early deaths)', 1),
#  ('Evidence of very low probability to success. No safety issues.', 1),
#  ('medical/ethical reasons', 1),
#  ('Terminated before starting due to need for IND determined by FDA.', 1),
#  ('Frequent adverse events occurred early in treatment with poor tolerability.',
#   1),
#  ('Drug toxicity', 1),
#  ('Terminated because primary efficacy parameter failed to demonstrate statistically significant    difference between memantine and placebo in controlled trials',
#   1),
#  ('Evidence of very low probability to success. No safety issues', 1),
#  ('Study was not approved by Health Surveillance Agency', 1),
#  ('missed endpoint of meaningful clinical benefit, compared to prednisolone 2.7mg',
#   1),
#  ('GLP-2 Drug product stability concerns', 1),
#  ('Decision taken to halt progression of mefloquine as a potential partner for OZ439 as a single    dose cure due to low probability of success',
#   1),
#  ('Substantial benefit was observed in the active treatment group', 1),
#  ('Registration of the medicine is no longer being pursued in South Korea, Taiwan or Vietnam',
#   1),
#  ('FDA placed a clinical hold on the Pediatric Program requiring retigabine discontinuation in    subjects; early termination allows for timely reporting of results.',
#   1),
#  ('Change in clinical strategy.', 1),
#  ('Study transferring to another facility', 1),
#  ('low inclusion', 1),
#  ('awaiting FDA approval for next dose group', 1),
#  ('withdrawn by industry', 1),
#  ('Lack of efficacy with one month of treatement', 1),
#  ('H1N1 pandemic concluded', 1),
#  ('difficulties to include patients', 1),
#  ('Unable to secure drug.', 1),
#  ('Because the inclusion rate was lower than expected.', 1),
#  ('Based on the previous study results, inactivated EV71 vaccine with aluminum adjuvant was    elected to be used for the efficacy Phase III study.',
#   1),
#  ('Study was closed due to recommendations of performing a PK study first.',
#   1),
#  ('Telaprevir will not be used in NL, no more inclusions are expected.', 1),
#  ('Protocol modification', 1),
#  ('because a significant decrease of viable candidates for the study.', 1),
#  ('company stopped production of study drug due to excessive toxicities', 1),
#  ('Strategic decision not to proceed with the opening of this study. There are no concerns over    the safety or quality of the investigational products involved.',
#   1),
#  ('drug company withdrww support following a re-examination of the benefit-risk assessment for    the investigational use of imetelstat in this population',
#   1),
#  ('Major amendment - change in design', 1),
#  ('The DSMB conducted an interim analysis on overall survival, which showed that the treatment    arm did not demonstrate a sufficient improvement in OS vs. placebo.',
#   1),
#  ('Low cure rate in the study (fluconazole) group', 1),
#  ('Investigator is leaving the institution.', 1),
#  ('Lack of Efficacy', 1),
#  ('Closed by sponsor', 1),
#  ('Drug reformulation', 1),
#  ("DSMB's decision following the first step analysis", 1),
#  ('Study terminated due to lack of efficacy', 1),
#  ('Publication of recent trials showing no effect of EPO in TBI substantially reduced equipoise    about this study.',
#   1),
#  ('All Amgen sponsored AMG102 clinical studies were terminated following a pre-planned Data    Monitoring Committee safety review of study 20070622.',
#   1),
#  ('occurrence of a serious adverse event', 1),
#  ('Principle Investigator is moving to another institution and plans to restart this proctocol in    the new location.',
#   1),
#  ('Lack of internal resources', 1),
#  ('the study was not feasible', 1),
#  ('Discrepancies in medication orders', 1),
#  ('Company decision', 1)]

# %%
repo_df = pd.concat([success_df, fail_df], ignore_index=True, sort=False)

xref_df = pd.read_table(
    'https://raw.githubusercontent.com/dhimmel/disease-ontology/'
    '75050ea2d4f60e745d3f3578ae03560a2cc0e444/data/xrefs-prop-slim.tsv')
umls_xref_df = xref_df.query('resource == "UMLS"')

full_df = (repo_df
 .merge(umls_xref_df, left_on='ind_id', right_on='resource_id')
 .drop(['resource', 'resource_id'], axis=1)
)

# Subset data to those which succeeded or which had (by very simplified 
#   heuristics) a functional reason for failure.
pred_df = (
    full_df
    .query('label == 1 or functional_failure == True')
)

pred_df.to_csv('repoDB_filtered.tsv', sep='\t', index=False)
